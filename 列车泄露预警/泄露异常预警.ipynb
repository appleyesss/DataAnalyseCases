# %% [markdown]
# # 一、建模场景分析

# %% [markdown]
# ## 1.1 建模目的

# %% [markdown]
# 在制动系统中，总风管是连接总风缸和制动系统以及其他用风设备的管路，总风缸由风源系统充风获得压力空气并存储，供给列车上所有的用风模块。管路、橡胶件、管路接头的密封性能下降具有严重的危害性，它不仅妨碍了列车的正常运行，损害了列车的寿命，更危害了顾客的安全。

# %% [markdown]
# ![](./制动系统简化模型图.png)

# %% [markdown]
# 因此针对由于管路、橡胶件、管路接头的密封性能下降，开发泄漏预警算法是极为重要的。开发泄漏预警算法分为总风管路泄漏故障和制动缸及相连管路泄漏故障，通过分析空压机的启停，制动过程消耗的压力空气，以及两者泄漏的压力空气之间的机理关系进行模型的建立。

# %% [markdown]
# ## 1.2 建模环境

# %% [markdown]
# Windows10 Python 3.7.3
#
# pandas==0.24.2

# %%
import pandas as pd
import os, json

# %% [markdown]
# # 二、读取数据

# %%
data_file_name = 'data_d16_V1.csv'
data = pd.read_csv(data_file_name)

# %%
data
# Out:
#                            time  CTPCBC_制动_空压机组1运行  CTPCBC_制动_空压机组2运行  \
# 0       2020-07-16 21:00:18.138                0.0                0.0
# 1       2020-07-16 21:00:18.769                0.0                0.0
# 2       2020-07-16 21:00:18.917                0.0                0.0
# 3       2020-07-16 21:00:19.487                0.0                0.0
# 4       2020-07-16 21:00:19.654                0.0                0.0
# 5       2020-07-16 21:00:20.250                0.0                0.0
# 6       2020-07-16 21:00:20.421                0.0                0.0
# 7       2020-07-16 21:00:21.008                0.0                0.0
# 8       2020-07-16 21:00:21.182                0.0                0.0
# 9       2020-07-16 21:00:21.737                0.0                0.0
# 10      2020-07-16 21:00:21.886                0.0                0.0
# 11      2020-07-16 21:00:22.485                0.0                0.0
# 12      2020-07-16 21:00:22.641                0.0                0.0
# 13      2020-07-16 21:00:23.236                0.0                0.0
# 14      2020-07-16 21:00:23.411                0.0                0.0
# 15      2020-07-16 21:00:23.977                0.0                0.0
# 16      2020-07-16 21:00:24.169                0.0                0.0
# 17      2020-07-16 21:00:24.743                0.0                0.0
# 18      2020-07-16 21:00:24.901                0.0                0.0
# 19      2020-07-16 21:00:25.497                0.0                0.0
# 20      2020-07-16 21:00:25.662                0.0                0.0
# 21      2020-07-16 21:00:26.256                0.0                0.0
# 22      2020-07-16 21:00:26.406                0.0                0.0
# 23      2020-07-16 21:00:26.995                0.0                0.0
# 24      2020-07-16 21:00:27.164                0.0                0.0
# 25      2020-07-16 21:00:27.736                0.0                0.0
# 26      2020-07-16 21:00:27.895                0.0                0.0
# 27      2020-07-16 21:00:28.488                0.0                0.0
# 28      2020-07-16 21:00:28.665                0.0                0.0
# 29      2020-07-16 21:00:29.243                0.0                0.0
# ...                         ...                ...                ...
# 100597  2020-07-16 14:59:52.466                0.0                0.0
# 100598  2020-07-16 14:59:52.811                0.0                0.0
# 100599  2020-07-16 14:59:53.224                0.0                0.0
# 100600  2020-07-16 14:59:53.563                0.0                0.0
# 100601  2020-07-16 14:59:54.001                0.0                0.0
# 100602  2020-07-16 14:59:54.309                0.0                0.0
# 100603  2020-07-16 14:59:54.713                0.0                0.0
# 100604  2020-07-16 14:59:55.046                0.0                0.0
# 100605  2020-07-16 14:59:55.482                0.0                0.0
# 100606  2020-07-16 14:59:55.835                0.0                0.0
# 100607  2020-07-16 14:59:56.227                0.0                0.0
# 100608  2020-07-16 14:59:56.563                0.0                0.0
# 100609  2020-07-16 14:59:56.978                0.0                0.0
# 100610  2020-07-16 14:59:57.315                0.0                0.0
# 100611  2020-07-16 14:59:57.709                0.0                0.0
# 100612  2020-07-16 14:59:58.034                0.0                0.0
# 100613  2020-07-16 14:59:58.455                0.0                0.0
# 100614  2020-07-16 14:59:58.812                0.0                0.0
# 100615  2020-07-16 14:59:59.231                0.0                0.0
# 100616  2020-07-16 14:59:59.557                0.0                0.0
# 100617  2020-07-16 14:59:59.976                0.0                0.0
# 100618  2020-07-16 15:00:00.286                0.0                0.0
# 100619  2020-07-16 15:00:00.716                0.0                0.0
# 100620  2020-07-16 15:00:01.047                0.0                0.0
# 100621  2020-07-16 15:00:01.467                0.0                0.0
# 100622  2020-07-16 15:00:01.814                0.0                0.0
# 100623  2020-07-16 15:00:02.232                0.0                0.0
# 100624  2020-07-16 15:00:02.561                0.0                0.0
# 100625  2020-07-16 15:00:02.986                0.0                0.0
# 100626  2020-07-16 15:00:03.293                0.0                0.0
#
#         BC1CT_制动_A1车B1架制动施加
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0
# 5                       1.0
# 6                       1.0
# 7                       1.0
# 8                       1.0
# 9                       1.0
# 10                      1.0
# 11                      1.0
# 12                      1.0
# 13                      1.0
# 14                      1.0
# 15                      1.0
# 16                      1.0
# 17                      1.0
# 18                      1.0
# 19                      1.0
# 20                      1.0
# 21                      1.0
# 22                      1.0
# 23                      1.0
# 24                      1.0
# 25                      1.0
# 26                      1.0
# 27                      1.0
# 28                      1.0
# 29                      1.0
# ...                     ...
# 100597                  1.0
# 100598                  1.0
# 100599                  1.0
# 100600                  1.0
# 100601                  1.0
# 100602                  1.0
# 100603                  1.0
# 100604                  1.0
# 100605                  1.0
# 100606                  1.0
# 100607                  1.0
# 100608                  1.0
# 100609                  1.0
# 100610                  1.0
# 100611                  1.0
# 100612                  1.0
# 100613                  1.0
# 100614                  1.0
# 100615                  1.0
# 100616                  1.0
# 100617                  1.0
# 100618                  1.0
# 100619                  1.0
# 100620                  1.0
# 100621                  1.0
# 100622                  1.0
# 100623                  1.0
# 100624                  1.0
# 100625                  1.0
# 100626                  1.0
#
# [100627 rows x 4 columns]

# %% [markdown]
# # 三、特征生成

# %%
feature_file_name = 'brake-v1.csv'
feature_data = pd.read_csv(feature_file_name)

# %% [markdown]
# 根据建模公式生成特征空压机工作率，制动频率，制动缸保压率

# %%
time_count_move_1 = data['CTPCBC_制动_空压机组1运行'].sum()
time_count_move_2 = data['CTPCBC_制动_空压机组2运行'].sum()
time_lenth = data.shape[0]
brake_diff = data['BC1CT_制动_A1车B1架制动施加'].diff()
brake_count = brake_diff[brake_diff == 1].count()
brake_time = data['BC1CT_制动_A1车B1架制动施加'].sum()
date_time = str(str(pd.to_datetime(data['time'][0]))[:10])
time_count = time_count_move_1 + time_count_move_2

# %%
#空压机
ratio = time_count / time_lenth
ratio

# %%
#制动频率
brake_count_ratio = brake_count / time_lenth
#制动缸保压率
brake_time_ratio = brake_time / time_lenth

# %%
feature_data = feature_data.append({'time': date_time, 'ratio':ratio, 'brake_count':brake_count_ratio, 'brake_time':brake_time_ratio
                                   ,'time_lenth': time_lenth},ignore_index=True)
feature_data
# Out:
#           time     ratio  brake_count  brake_time  time_lenth
# 0   2020-07-06  0.154980     0.036186    0.443248       31946
# 1   2020-07-07  0.146846     0.008929    0.491551       28111
# 2   2020-07-08  0.189425     0.021811    0.732835       11783
# 3   2020-07-09  0.164853     0.020050    0.396308       55959
# 4   2020-07-10  0.165328     0.006245    0.386093       54764
# 5   2020-07-11  0.107576     0.074407    0.715734      102988
# 6   2020-07-12  0.456347     0.073163    0.724482       51474
# 7   2020-07-13  0.128562     0.113171    0.618533       80568
# 8   2020-07-14  0.152027     0.091900    0.492411       71349
# 9   2020-07-15  0.169687     0.087884    0.487911       80902
# 10  2020-07-16  0.108281     0.099317    0.640206      100627

# %% [markdown]
# # 三、模型训练

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
file_feature_name = "brake-v1.csv"
old_file_name = "statistics.csv"

# %%
df = pd.read_csv(old_file_name)
df = df.iloc[:150, :]
df
# Out:
#         brake    tratio     ratio
# 0    0.002778  0.842222  0.049444
# 1    0.004226  0.718512  0.154583
# 2    0.009826  0.369792  0.188646
# 3    0.010926  0.394222  0.230074
# 4    0.001667  0.941282  0.056282
# 5    0.009752  0.377801  0.197340
# 6    0.011032  0.396111  0.197183
# 7    0.009886  0.365303  0.213485
# 8    0.000833  0.998030  0.044091
# 9    0.000000  1.000000  0.047083
# 10   0.000519  0.957222  0.076370
# 11   0.006538  0.406190  0.180806
# 12   0.000595  0.955417  0.048988
# 13   0.006632  0.384439  0.236298
# 14   0.006742  0.388220  0.185833
# 15   0.006735  0.379813  0.222092
# 16   0.006993  0.389221  0.189312
# 17   0.006560  0.381330  0.245975
# 18   0.006985  0.386367  0.185356
# 19   0.006702  0.391223  0.220213
# 20   0.006572  0.389754  0.180795
# 21   0.000614  0.953158  0.069035
# 22   0.006754  0.379228  0.190561
# 23   0.003542  0.662153  0.185590
# 24   0.006905  0.400806  0.196740
# 25   0.006283  0.358900  0.223100
# 26   0.006818  0.384318  0.196023
# 27   0.006960  0.408901  0.227802
# 28   0.000542  0.947583  0.051375
# 29   0.006577  0.372921  0.220197
# ..        ...       ...       ...
# 120  0.006193  0.422925  0.192941
# 121  0.006159  0.372587  0.181587
# 122  0.006757  0.372047  0.173913
# 123  0.000833  0.980833  0.037083
# 124  0.000052  0.999948  0.037135
# 125  0.002333  0.926333  0.097000
# 126  0.000441  0.947157  0.059314
# 127  0.002083  0.850000  0.084167
# 128  0.000000  1.000000  0.000000
# 129  0.000000  0.000000  0.000000
# 130  0.000000  1.000000  0.035741
# 131  0.000000  0.000000  0.000000
# 132  0.000000  0.000000  0.000000
# 133  0.000833  0.973889  0.047222
# 134  0.000000  0.000000  0.000000
# 135  0.000667  0.950143  0.063571
# 136  0.001515  0.802424  0.066667
# 137  0.000000  0.000000  0.000000
# 138  0.000000  0.000000  0.000000
# 139  0.001429  0.954206  0.124206
# 140  0.000000  0.000000  0.000000
# 141  0.000000  0.000000  0.000000
# 142  0.000000  1.000000  0.079167
# 143  0.001875  0.814167  0.067917
# 144  0.000000  0.000000  0.000000
# 145  0.000000  0.902778  0.093333
# 146  0.000833  0.998333  0.000000
# 147  0.000175  0.999825  0.042544
# 148  0.000000  0.000000  0.000000
# 149  0.000156  0.996875  0.056667
#
# [150 rows x 3 columns]

# %%
ratio_list = []
b_count_list = []
b_time_list = []

# %%
df = pd.read_csv(old_file_name, nrows=150)
BASE_SURFACE_X = df['brake']
BASE_SURFACE_Y = df['tratio']
A = 13.2314
B = 0.01858
C = 0.05499
BASE_SURFACE_Z = BASE_SURFACE_X * A + BASE_SURFACE_Y * B + C
base_x = np.hstack((np.array(BASE_SURFACE_X).reshape(-1,1) , np.array(BASE_SURFACE_Y).reshape(-1,1)))
base_y = np.array(BASE_SURFACE_Z).reshape(-1,1)

# %%
BASE_SURFACE_X
# Out:
# 0      0.002778
# 1      0.004226
# 2      0.009826
# 3      0.010926
# 4      0.001667
# 5      0.009752
# 6      0.011032
# 7      0.009886
# 8      0.000833
# 9      0.000000
# 10     0.000519
# 11     0.006538
# 12     0.000595
# 13     0.006632
# 14     0.006742
# 15     0.006735
# 16     0.006993
# 17     0.006560
# 18     0.006985
# 19     0.006702
# 20     0.006572
# 21     0.000614
# 22     0.006754
# 23     0.003542
# 24     0.006905
# 25     0.006283
# 26     0.006818
# 27     0.006960
# 28     0.000542
# 29     0.006577
#          ...
# 120    0.006193
# 121    0.006159
# 122    0.006757
# 123    0.000833
# 124    0.000052
# 125    0.002333
# 126    0.000441
# 127    0.002083
# 128    0.000000
# 129    0.000000
# 130    0.000000
# 131    0.000000
# 132    0.000000
# 133    0.000833
# 134    0.000000
# 135    0.000667
# 136    0.001515
# 137    0.000000
# 138    0.000000
# 139    0.001429
# 140    0.000000
# 141    0.000000
# 142    0.000000
# 143    0.001875
# 144    0.000000
# 145    0.000000
# 146    0.000833
# 147    0.000175
# 148    0.000000
# 149    0.000156
# Name: brake, Length: 150, dtype: float64

# %%
np.array(BASE_SURFACE_X).reshape(-1,1)
# Out:
# array([[2.7777780e-03],
#        [4.2261900e-03],
#        [9.8263890e-03],
#        [1.0925926e-02],
#        [1.6666670e-03],
#        [9.7517730e-03],
#        [1.1031746e-02],
#        [9.8863640e-03],
#        [8.3333300e-04],
#        [0.0000000e+00],
#        [5.1851900e-04],
#        [6.5384620e-03],
#        [5.9523800e-04],
#        [6.6315790e-03],
#        [6.7424240e-03],
#        [6.7346940e-03],
#        [6.9927540e-03],
#        [6.5602840e-03],
#        [6.9850190e-03],
#        [6.7021280e-03],
#        [6.5719700e-03],
#        [6.1403500e-04],
#        [6.7543860e-03],
#        [3.5416670e-03],
#        [6.9047620e-03],
#        [6.2833330e-03],
#        [6.8181820e-03],
#        [6.9597070e-03],
#        [5.4166700e-04],
#        [6.5770610e-03],
#        [7.3148150e-03],
#        [1.0540541e-02],
#        [1.0387597e-02],
#        [4.0476200e-04],
#        [1.2121200e-04],
#        [2.9738560e-03],
#        [9.3840580e-03],
#        [9.1666670e-03],
#        [1.0227273e-02],
#        [7.2142860e-03],
#        [2.7688170e-03],
#        [6.2820510e-03],
#        [6.2037040e-03],
#        [6.3483150e-03],
#        [0.0000000e+00],
#        [4.3379000e-04],
#        [3.0300000e-05],
#        [2.5179900e-04],
#        [1.7216120e-03],
#        [2.8985500e-04],
#        [2.0224720e-03],
#        [2.8985500e-04],
#        [2.3148100e-04],
#        [1.5000000e-03],
#        [0.0000000e+00],
#        [3.4523800e-04],
#        [6.3859650e-03],
#        [6.1827960e-03],
#        [6.3148150e-03],
#        [6.6666670e-03],
#        [3.0833330e-03],
#        [6.6111110e-03],
#        [9.9645390e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.3333300e-04],
#        [5.7575760e-03],
#        [5.2777780e-03],
#        [9.8913040e-03],
#        [9.3971630e-03],
#        [6.9517540e-03],
#        [6.2454210e-03],
#        [2.2146120e-03],
#        [6.2403100e-03],
#        [1.2626260e-03],
#        [6.0975600e-04],
#        [6.2581700e-03],
#        [3.1666667e-02],
#        [0.0000000e+00],
#        [6.6845880e-03],
#        [6.6853930e-03],
#        [6.1378210e-03],
#        [3.2407410e-03],
#        [6.6666670e-03],
#        [6.1447810e-03],
#        [6.1512030e-03],
#        [6.6666670e-03],
#        [3.4037600e-04],
#        [6.4776630e-03],
#        [3.8011700e-04],
#        [6.1326860e-03],
#        [6.4157710e-03],
#        [0.0000000e+00],
#        [2.1258503e-02],
#        [9.5918370e-03],
#        [9.5289860e-03],
#        [8.9743600e-04],
#        [9.7163120e-03],
#        [0.0000000e+00],
#        [9.0522880e-03],
#        [1.8888890e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [6.8181800e-04],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.7543900e-04],
#        [2.6616920e-03],
#        [6.1601310e-03],
#        [5.6871350e-03],
#        [5.9682540e-03],
#        [6.0457520e-03],
#        [6.3166670e-03],
#        [6.3573880e-03],
#        [6.6491230e-03],
#        [1.7697590e-03],
#        [6.1666670e-03],
#        [6.3230240e-03],
#        [2.5925900e-04],
#        [6.1928100e-03],
#        [6.1587300e-03],
#        [6.7572460e-03],
#        [8.3333300e-04],
#        [5.2100000e-05],
#        [2.3333330e-03],
#        [4.4117600e-04],
#        [2.0833330e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [8.3333300e-04],
#        [0.0000000e+00],
#        [6.6666700e-04],
#        [1.5151520e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.4285710e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.8750000e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [8.3333300e-04],
#        [1.7543900e-04],
#        [0.0000000e+00],
#        [1.5625000e-04]])

# %%
His=pd.read_csv(file_feature_name)
for key in sorted(His['time']):
    ratio_list.append(His[His['time']== key]['ratio'].values[0])
    b_count_list.append(His[His['time']== key]['brake_count'].values[0])
    b_time_list.append(His[His['time']== key]['brake_time'].values[0])
    date_time = key
    
if len(ratio_list)>=10:
    fit1 = np.array(ratio_list[-10:], dtype ='float64').reshape(-1,1)#转换成一列
    fit2 = np.array(b_count_list[-10:], dtype ='float64').reshape(-1,1)
    fit3 = np.array(b_time_list[-10:], dtype ='float64').reshape(-1,1)
    fit4 = np.hstack((fit2,fit3))
    Model = LinearRegression()
    Model.fit(np.vstack((base_x,fit4)),np.vstack((base_y,fit1)))
    dict_LR = {'time':date_time, 'A':float(Model.coef_[0][0]), 'B':float(Model.coef_[0][1]), 'C':float(Model.intercept_)}

param_data = pd.DataFrame([dict_LR])
param_data.to_csv('model.csv', index= False)

# %%
#reshape(1,-1)转化成1行：
#reshape(2,-1)转换成两行：
#reshape(-1,1)转换成1列：
#reshape(-1,2)转化成两列

# %%
param_data
# Out:
#           A         B         C        time
# 0  1.661305 -0.036643  0.133181  2020-07-15

# %%
ratio_list
# Out:
# [0.15498027922118576,
#  0.14684643022304436,
#  0.18942544343545786,
#  0.16485283868546616,
#  0.16532758746621867,
#  0.1075756398803744,
#  0.45634689357734,
#  0.12856220832092147,
#  0.15202735847734375,
#  0.16968678153815728]

# %% [markdown]
# # 四、模型预测

# %%
file_name = 'model.csv'
df = pd.read_csv(file_name)
df
# Out:
#           A         B         C        time
# 0  1.661305 -0.036643  0.133181  2020-07-15

# %%
df['C'][0]
# Out:
# 0.13318063979749264

# %%
if df['C'][0]> 0.05499:
    df['result']= '总风管泄露'
elif df['B'][0]> 0.01858:
    df['result']= '制动系统泄露'
else:
    df['result']= '正常'

df
# Out:
#           A         B         C        time result
# 0  1.661305 -0.036643  0.133181  2020-07-15    总风管
